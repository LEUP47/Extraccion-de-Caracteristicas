# %%
import funpymodeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling.exploratory import freq_tbl

# %%
mr2=pd.read_csv("mr2.csv")

# %%
#obtengo un analisis de las variables categoricas
freq_tbl(mr2)
# Out:
#                                _record_id  frequency  percentage  \
# 0    dff2998e-af74-4de6-8efd-488aca24e67b          1    0.005848
# 1    53c25f08-1c1b-4c1c-97d5-b45c940735cc          1    0.005848
# 2    af5c48b5-a916-47a6-aacc-1128ea1e728e          1    0.005848
# 3    4790411b-df1d-44f0-a659-6d99e26ae765          1    0.005848
# 4    e70db20a-25db-412b-9a71-7df285c92a3d          1    0.005848
# ..                                    ...        ...         ...
# 166  75bcc709-90ff-4db7-bb82-293f2f72f3ae          1    0.005848
# 167  bd59c8b6-81cb-4698-8cfd-dbab7f01ef21          1    0.005848
# 168  94b1c6bc-1fb8-4895-aacc-c2604dc12b93          1    0.005848
# 169  d9ff4194-657e-4fb4-b5f4-b7e8b350a646          1    0.005848
# 170  bf720ff0-3b7d-47ed-ba49-f5d4bfb7293c          1    0.005848
#
#      cumulative_perc
# 0           0.005848
# 1           0.011696
# 2           0.017544
# 3           0.023392
# 4           0.029240
# ..               ...
# 166         0.976608
# ...

# %%
table1=freq_tbl(mr2['260_technology_scalable'])
table1
# Out:
#           260_technology_scalable  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         63    0.368421         0.368421
# 1                      De acuerdo         50    0.292398         0.660819
# 2                   En desacuerdo         35    0.204678         0.865497
# 3  Ni de acuerdo ni en desacuerdo         12    0.070175         0.935673
# 4        Totalmente en desacuerdo          6    0.035088         0.970760
# 5                               0          5    0.029240         1.000000

# %%
filtro1=table1[table1['frequency']>5]
filtro1
# Out:
#           260_technology_scalable  frequency  percentage  cumulative_perc
# 0           Totalmente de acuerdo         63    0.368421         0.368421
# 1                      De acuerdo         50    0.292398         0.660819
# 2                   En desacuerdo         35    0.204678         0.865497
# 3  Ni de acuerdo ni en desacuerdo         12    0.070175         0.935673
# 4        Totalmente en desacuerdo          6    0.035088         0.970760

# %%
filtro_index=filtro1.set_index('260_technology_scalable')
filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 260_technology_scalable
# Totalmente de acuerdo                  63    0.368421         0.368421
# De acuerdo                             50    0.292398         0.660819
# En desacuerdo                          35    0.204678         0.865497
# Ni de acuerdo ni en desacuerdo         12    0.070175         0.935673
# Totalmente en desacuerdo                6    0.035088         0.970760

# %%
filtro_index_frequency=filtro_index.drop(['percentage','cumulative_perc'],axis=1)
filtro_index_frequency
# Out:
#                                 frequency
# 260_technology_scalable
# Totalmente de acuerdo                  63
# De acuerdo                             50
# En desacuerdo                          35
# Ni de acuerdo ni en desacuerdo         12
# Totalmente en desacuerdo                6

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f%%")
# Out:
# <Axes: ylabel='frequency'>
