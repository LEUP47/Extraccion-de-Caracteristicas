# %%
import funpymodeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling.exploratory import freq_tbl

# %%
mr2=pd.read_csv("mr2.csv")

# %%
table1=freq_tbl(mr2['193_sales_planning_tools'])
table1
# Out:
#                    193_sales_planning_tools  frequency  percentage  \
# 0                                   Ninguna         71    0.415205
# 1                                  Cuaderno         32    0.187135
# 2                    Software especializado         29    0.169591
# 3                                     Excel         16    0.093567
# 4                                         0          5    0.029240
# 5                            Cuaderno,Excel          4    0.023392
# 6                          Cuaderno,Ninguna          2    0.011696
# 7                                En físico           2    0.011696
# 8                                    Mental          1    0.005848
# 9                      Por temporada de pan          1    0.005848
# 10                           Sobre demanda           1    0.005848
# 11                                    Other          1    0.005848
# 12  Aplicación móvil,Software especializado          1    0.005848
# 13             Excel,Software especializado          1    0.005848
# 14                                Catálogo           1    0.005848
# 15                           Redes sociales          1    0.005848
# 16                         Aplicación móvil          1    0.005848
# 17                   Aplicación móvil,Excel          1    0.005848
#
#     cumulative_perc
# 0          0.415205
# 1          0.602339
# 2          0.771930
# 3          0.865497
# 4          0.894737
# 5          0.918129
# 6          0.929825
# 7          0.941520
# 8          0.947368
# 9          0.953216
# 10         0.959064
# 11         0.964912
# 12         0.970760
# 13         0.976608
# 14         0.982456
# 15         0.988304
# 16         0.994152
# 17         1.000000

# %%
filtro1=table1[table1['frequency']>5]
filtro1
# Out:
#   193_sales_planning_tools  frequency  percentage  cumulative_perc
# 0                  Ninguna         71    0.415205         0.415205
# 1                 Cuaderno         32    0.187135         0.602339
# 2   Software especializado         29    0.169591         0.771930
# 3                    Excel         16    0.093567         0.865497

# %%
filtro_index=filtro1.set_index('193_sales_planning_tools')
filtro_index
# Out:
#                           frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# Ninguna                          71    0.415205         0.415205
# Cuaderno                         32    0.187135         0.602339
# Software especializado           29    0.169591         0.771930
# Excel                            16    0.093567         0.865497

# %%
filtro_index_frequency=filtro_index.drop(['percentage','cumulative_perc'],axis=1)
filtro_index_frequency
# Out:
#                           frequency
# 193_sales_planning_tools
# Ninguna                          71
# Cuaderno                         32
# Software especializado           29
# Excel                            16

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f%%")
# Out:
# <Axes: ylabel='frequency'>
