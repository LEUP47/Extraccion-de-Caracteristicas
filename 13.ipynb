# %%
import funpymodeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling.exploratory import freq_tbl

# %%
mr2=pd.read_csv("mr2.csv")

# %%
table1=freq_tbl(mr2['69_why_not_services'])
table1
# Out:
#                                   69_why_not_services  frequency  percentage  \
# 0                            No conozco los servicios         53    0.309942
# 1                                         Es muy caro         18    0.105263
# 2                                Se quiere involucrar         15    0.087719
# 3            No quiero involucrarme con la tecnología         14    0.081871
# 4                  No son funcionales para mi empresa         14    0.081871
# 5             No creo que represente grandes ingresos         10    0.058480
# 6                                                   0          9    0.052632
# 7                                    no es requerido           7    0.040936
# 8                                          no lo vale          6    0.035088
# 9   No conozco los servicios,No quiero involucrarm...          5    0.029240
# 10  Es muy caro,No quiero involucrarme con la tecn...          4    0.023392
# 11                                 Apenas son nuevos           3    0.017544
# 12  Es muy caro,No conozco los servicios,No creo q...          3    0.017544
# 13                                      Pura taqueria          2    0.011696
# 14                                 no estamos listos           2    0.011696
# 15                            Es exclusivo panadería           1    0.005848
# 16  Es muy caro,No creo que represente grandes ing...          1    0.005848
# 17                                      Se vende ropa          1    0.005848
# 18  No creo que represente grandes ingresos,No qui...          1    0.005848
# 19                          No sabe cómo involucrarse          1    0.005848
# 20                                         mo lo vale          1    0.005848
#
#     cumulative_perc
# 0          0.309942
# 1          0.415205
# 2          0.502924
# 3          0.584795
# 4          0.666667
# 5          0.725146
# 6          0.777778
# 7          0.818713
# 8          0.853801
# 9          0.883041
# 10         0.906433
# 11         0.923977
# 12         0.941520
# 13         0.953216
# 14         0.964912
# 15         0.970760
# 16         0.976608
# 17         0.982456
# 18         0.988304
# 19         0.994152
# 20         1.000000

# %%
filtro1=table1[table1['frequency']>5]
filtro1
# Out:
#                         69_why_not_services  frequency  percentage  \
# 0                  No conozco los servicios         53    0.309942
# 1                               Es muy caro         18    0.105263
# 2                      Se quiere involucrar         15    0.087719
# 3  No quiero involucrarme con la tecnología         14    0.081871
# 4        No son funcionales para mi empresa         14    0.081871
# 5   No creo que represente grandes ingresos         10    0.058480
# 6                                         0          9    0.052632
# 7                          no es requerido           7    0.040936
# 8                                no lo vale          6    0.035088
#
#    cumulative_perc
# 0         0.309942
# 1         0.415205
# 2         0.502924
# 3         0.584795
# 4         0.666667
# 5         0.725146
# 6         0.777778
# 7         0.818713
# 8         0.853801

# %%
filtro_index=filtro1.set_index('69_why_not_services')
filtro_index
# Out:
#                                           frequency  percentage  \
# 69_why_not_services
# No conozco los servicios                         53    0.309942
# Es muy caro                                      18    0.105263
# Se quiere involucrar                             15    0.087719
# No quiero involucrarme con la tecnología         14    0.081871
# No son funcionales para mi empresa               14    0.081871
# No creo que represente grandes ingresos          10    0.058480
# 0                                                 9    0.052632
# no es requerido                                   7    0.040936
# no lo vale                                        6    0.035088
#
#                                           cumulative_perc
# 69_why_not_services
# No conozco los servicios                         0.309942
# Es muy caro                                      0.415205
# Se quiere involucrar                             0.502924
# No quiero involucrarme con la tecnología         0.584795
# No son funcionales para mi empresa               0.666667
# No creo que represente grandes ingresos          0.725146
# 0                                                0.777778
# no es requerido                                  0.818713
# no lo vale                                       0.853801

# %%
filtro_index_frequency=filtro_index.drop(['percentage','cumulative_perc'],axis=1)
filtro_index_frequency
# Out:
#                                           frequency
# 69_why_not_services
# No conozco los servicios                         53
# Es muy caro                                      18
# Se quiere involucrar                             15
# No quiero involucrarme con la tecnología         14
# No son funcionales para mi empresa               14
# No creo que represente grandes ingresos          10
# 0                                                 9
# no es requerido                                   7
# no lo vale                                        6

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_index["frequency"].plot(kind='pie', figsize=(10,5), autopct="%0.1f%%")
# Out:
# <Axes: ylabel='frequency'>
